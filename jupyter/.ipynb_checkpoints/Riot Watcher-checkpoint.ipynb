# %%
pip install riotwatcher

# %%
import pandas as pd
import requests
import datetime
import base64
import os
import pandas as pd
import re
import datetime as dt
from riotwatcher import LolWatcher, ApiError
from pandas import json_normalize

# %%
lol_watcher = LolWatcher('RGAPI-beefeee6-bcef-480e-bcdc-12d3a372ece0')

my_region = 'na1'

me = lol_watcher.summoner.by_name(my_region, 'Doublelift')
print(me)

# all objects are returned (by default) as a dict
# lets see if i got diamond yet (i probably didnt)
my_ranked_stats = lol_watcher.league.by_summoner(my_region, me['id'])
print(my_ranked_stats)

# First we get the latest version of the game from data dragon
versions = lol_watcher.data_dragon.versions_for_region(my_region)
champions_version = versions['n']['champion']

# Lets get some champions
current_champ_list = lol_watcher.data_dragon.champions(champions_version)
print(current_champ_list)

# For Riot's API, the 404 status code indicates that the requested data wasn't found and
# should be expected to occur in normal operation, as in the case of a an
# invalid summoner name, match ID, etc.
#
# The 429 status code indicates that the user has sent too many requests
# in a given amount of time ("rate limiting").

try:
    response = lol_watcher.summoner.by_name(my_region, 'this_is_probably_not_anyones_summoner_name')
except ApiError as err:
    if err.response.status_code == 429:
        print('We should retry in {} seconds.'.format(err.headers['Retry-After']))
        print('this retry-after is handled by default by the RiotWatcher library')
        print('future requests wait until the retry-after time passes')
    elif err.response.status_code == 404:
        print('Summoner with that ridiculous name not found.')
    else:
        raise

# %%
test = lol_watcher.champion_mastery.by_summoner(my_region, 'iqHggxw_J_90RXfoSzAqi9ITv-LmDdIFSFS-4z_qinnQnOY')
test_df = pd.DataFrame(test)

# %%
def get_summonerData(region, username):

        summoner = lol_watcher.summoner.by_name(my_region, username)
        summoner_df = pd.DataFrame([summoner])
        return summoner_df

summoner_df = get_summonerData(region, 'Doublelift')
summoner_df
# Out:
#                                                 id  \
# 0  iqHggxw_J_90RXfoSzAqi9ITv-LmDdIFSFS-4z_qinnQnOY
#
#                                         accountId  \
# 0  ii2YY7ub39QQCOdaAMjv--q9Ql2IkzJ1K-rwcdPuZj9RBg
#
#                                                puuid        name  \
# 0  KYNPFp49bqq2Q30Uzu6OLohdycwn0Nm5Ai1hkiPCeY9DWO...  Doublelift
#
#    profileIconId   revisionDate  summonerLevel
# 0           4568  1620947979000            250

# %%
def get_matchId(my_region, summoner_df, num_matches):
    account_id = summoner_df['accountId'][0]
    match = lol_watcher.match.matchlist_by_account(region=my_region, encrypted_account_id=account_id, end_index=num_matches, season=13)
    match_df = pd.DataFrame(match['matches'])
    match_id = match_df['gameId']
    return match_id

doublelift_match_ids = get_matchId(my_region, summoner_df, 2)
doublelift_match_ids
# Out:
# 0    3905384132
# 1    3905339340
# Name: gameId, dtype: int64

# %%
def get_stats(my_region, match_id):
    match_info = []
    stats = []
    stats_df = pd.DataFrame()
    
    for i in range(len(match_id)):
        data = lol_watcher.match.by_id(region = my_region, match_id = match_id[i])
        data_df = json_normalize(data)
        match_info = data_df['participants'].values.tolist() 
        match_df = pd.concat([pd.DataFrame(t) for t in match_info], axis=1)
        stats = match_df['stats'].values.tolist()
        temp_df = pd.concat([pd.DataFrame(s,index=[0]) for s in stats])
        stats_df = stats_df.append(temp_df)
    stats_df.reset_index(drop=True,inplace=True)    
    return stats_df

test = get_stats('na1',doublelift_match_ids)

# %%
test
# Out:
#     participantId    win  item0  item1  item2  item3  item4  item5  item6  \
# 0               1  False   1055   6671   2055   3006      0      0   3340
# 1               2  False   3044   6029      0   1054   1055   3047   3340
# 2               3  False   3067      0   3044   1001      0      0   3340
# 3               4  False      0   3191   3802   1082   3158      0   3340
# 4               5  False   2055   3117   3067   3105      0   3859   3364
# 5               6   True   3158   3068   1011   1057      0      0   3364
# 6               7   True   6673   1054   1055   3006   3086   2055   3363
# 7               8   True   1028   6029   3076   3047   1036   1055   3340
# 8               9   True   6671   1055   3006   1037   3036      0   3363
# 9              10   True   2065   3853      0   3158   3067   3108   3364
# 10              1  False   3179   3047   6692   3133   3035      0   3364
# 11              2  False   6673   3508   3006   1057   3051   1036   3363
# 12              3  False   4636   3020   1058   1056   1058   3916   3364
# 13              4  False   2031   2065   3853   3158   1004   1052   3364
# 14              5  False   6671   1055   3006   3036      0      0   3363
# 15              6   True   6656   4629   3157      0   1082   3158   3340
# 16              7   True   3078   3047   3074   1055   3044   1037   3364
# 17              8   True   1055   6672   3085   3031   1053   3006   3363
# 18              9   True      0   3190   3857   1006   3067   3047   3364
# 19             10   True   3041   3157   3916   2055   3020   4636   3364
#
#     kills  ...  perk4Var3  perk5  perk5Var1  perk5Var2  perk5Var3  \
# 0       1  ...          0   8135        101          3          0
# 1       1  ...          0   8453        366          0          0
# 2       0  ...          0   8105          1          0          0
# 3       1  ...          0   8347          0          0          0
# 4       1  ...          0   8321          1          0          0
# 5       3  ...          0   8429         25         15         16
# 6       5  ...         12   8453        190        169          0
# 7       2  ...          0   8473        484          0          0
# 8       7  ...          0   8345          3          0          0
# 9       3  ...          0   8345          3          0          0
# 10      6  ...          0   8135       1846          4          0
# 11      3  ...          0   8345          3          0          0
# 12      3  ...          0   8224        603          0          0
# 13      1  ...          0   8453        230       1712          0
# 14      0  ...          5   8345          3          0          0
# 15     10  ...          0   8347          0          0          0
# 16      4  ...          0   8242         31          0          0
# 17      7  ...          0   8135       2681          5          0
# 18      0  ...          0   8306         15          0          0
# 19      4  ...          0   8232          3         30          0
#
#     perkPrimaryStyle  perkSubStyle  statPerk0  statPerk1  statPerk2
# 0               8000          8100       5005       5008       5002
# 1               8000          8400       5008       5008       5002
# 2               8000          8100       5008       5008       5002
# 3               8000          8300       5008       5008       5002
# 4               8400          8300       5007       5002       5003
# 5               8000          8400       5007       5002       5001
# 6               8000          8400       5005       5008       5003
# 7               8000          8400       5005       5008       5002
# 8               8000          8300       5005       5008       5002
# 9               8400          8300       5008       5008       5002
# 10              8000          8100       5008       5008       5002
# 11              8000          8300       5005       5008       5002
# 12              8100          8200       5008       5008       5003
# 13              8200          8400       5008       5008       5002
# 14              8000          8300       5005       5008       5002
# 15              8000          8300       5008       5008       5002
# 16              8000          8400       5008       5008       5002
# 17              8000          8100       5005       5008       5002
# 18              8400          8300       5005       5002       5003
# 19              8100          8200       5005       5008       5002
#
# [20 rows x 102 columns]

# %%
def get_summonerName(my_region, match_id):
    match_info = []
    name_df = pd.DataFrame()
    
    for i in range(len(match_id)):
        data = lol_watcher.match.by_id(region = my_region, match_id = match_id[i])
        data_df = json_normalize(data['participantIdentities'])
        name_df = name_df.append(data_df)
        
    name_df = name_df.drop(columns=['participantId','player.currentPlatformId','player.currentAccountId','player.matchHistoryUri','player.profileIcon','player.platformId'])    
    name_df.reset_index(drop=True,inplace=True)
    return name_df

test1 = get_summonerName('na1',doublelift_match_ids)

# %%
test1
# Out:
#                                      player.accountId player.summonerName  \
# 0      ii2YY7ub39QQCOdaAMjv--q9Ql2IkzJ1K-rwcdPuZj9RBg          Doublelift
# 1   Cl4YEkXtBJnME7eH9kYEqlDgxnWa9xpVgoBpO36HGVv5WH...         Cozy Shroud
# 2   _R4cErxtKyHB5fEb-7HKj0RgdF49C01NM8mKgPqaRMjUJy...              þowerD
# 3      __S_bzD-vAZ6Ku6tg3rm7VFXx0Bgt3JWtyOunOkmbIPoTA               5fire
# 4   2xSjkLDwRA-TK466OkvP99zWvJ22so6_aJPA1HC9Auzax4...    Serious Gameplay
# 5   iVJddGNhzsW5WPDpM4GSDBF6vu3TmzAdniicGHKgn2zZZW...    pspspspsmeowmeow
# 6   m2sKKYwWJaJ9dl3zHuCoY_mlp6_6i-FipyMH7kubEN65Uv...         Tempest ttv
# 7      AIQhIQFuZWX233O9nuKtI3LMxtEAfV2qm0MiUkyz0b4KjA             Dragoon
# 8   IDDxiWI94jjyAW_pcr1NfZzKEuMyCXlKcs1eG-6-Lb-g4T...      Pieck is Waifu
# 9      NMl4mIYIfnPAAH6pT2fyTmmNxutH5V3rJNKW1nCNMCVCRw        I like Booba
# 10  ZkKBXQuS10T_f11ig3eLkw53lDHAhfVB3kG58ud16XsFRQ...       LeenK Nirvana
# 11  6kCLRADAr-TCB1ME03ND1QUGhSQPJ6rPlegZBLJ6DJmclK...    unga bunga kindo
# 12     __S_bzD-vAZ6Ku6tg3rm7VFXx0Bgt3JWtyOunOkmbIPoTA               5fire
# 13     h0n6KNRFD6rwSz2MBLQt3gs9SXdOxZ2y3a6OI3wKO4H71g            Good Boi
# 14  IDDxiWI94jjyAW_pcr1NfZzKEuMyCXlKcs1eG-6-Lb-g4T...      Pieck is Waifu
# 15     bB8DIPu6VGXo1lTNV9RR0WGAwUogiRYm8xmr36RX2xjTEA    Alicopter T3 Sub
# 16     2dLxZoMRMrRzmgNiCSgA4lezuZmOMvLZJff0xQTMteKRRQ          WC Qwacker
# 17     ii2YY7ub39QQCOdaAMjv--q9Ql2IkzJ1K-rwcdPuZj9RBg          Doublelift
# 18  0zb2VIVo-FBqIk98mDAQxGS-P2HCr02zk71Gd0vVNxchEs...           depresion
# 19    SysnZS-sN9AeZMW4GHy098_jbQ_1SP4vW11He7IG_AD-mns        Draven696969
#
#                                     player.summonerId
# 0     iqHggxw_J_90RXfoSzAqi9ITv-LmDdIFSFS-4z_qinnQnOY
# 1    zWQ1A_8FaR9psysYLIyS7MaCkAsXULSh_ZzGKRpsdpOqz6kw
# 2    0Sr4OjKxiEe105n6xEPW-S1USPKmNZBia4_AEAZyZJKZXwil
# 3     BUcAS_iVJVxAmCVqg8eG3NDvbnTp8wsT0l-wNS4EqYX96gk
# 4   sEqx0bfTMJiY52ZU831U6oBCdfv1sNgqk68Vj9LC32zjX1...
# 5    YcwF5hr5accBvq5VVWUajUmBIvokhmHByuDvyfRbInzZesut
# 6   EGMOeHLfeFw6cBjepKxMrsmUJ5oWfSNykvvVGhYcL6CdwV...
# 7     fVsMYQwM9zSqU09guMSgT2goBDQ5g1zQILvMrPQQoYed9-k
# 8    ne0WA3Mou5W67K3tGO1iUc3vR93VeHQCbsY2N_H5ucKzcY1_
# 9     mwYYtJgmLE7hQpFW58joBVtXzLHJRISR5jHcwFKUy84CNxg
# 10  so1qNAuD0x-wZErhV8jy6Rt6dwIrgRcddX19lQxr7YfzIb...
# 11  6maffPrpsHpTUB0V76pVuA9jfx2Stl7FNBytsiwu5-1lE3...
# 12    BUcAS_iVJVxAmCVqg8eG3NDvbnTp8wsT0l-wNS4EqYX96gk
# 13    nkBcD59OcoUVL3lLWeusrgserBowbKA_uGojzZuqG4dggvM
# 14   ne0WA3Mou5W67K3tGO1iUc3vR93VeHQCbsY2N_H5ucKzcY1_
# 15    T6In7sIiiYxmE4Liqa6bPcHMKAZrSNVx6dvfx32aYd9xdkU
# 16    eJDIDpmUOZShw96ReM1NuDZA2AySCmFW5Tdvgp0UOiWHTQY
# 17    iqHggxw_J_90RXfoSzAqi9ITv-LmDdIFSFS-4z_qinnQnOY
# 18  Qp1UYzo-Mp3i9BmhoTj2wruTR5YdyzbUQF8ILh4v9jeP7L...
# 19    luFgRdKx312jCmdeLV-CLv2GY_50A-PnOcAF3aLHjO6iJkE

# %%
df = test1.join(test,how='left')
df
# Out:
#                                      player.accountId player.summonerName  \
# 0      ii2YY7ub39QQCOdaAMjv--q9Ql2IkzJ1K-rwcdPuZj9RBg          Doublelift
# 1   Cl4YEkXtBJnME7eH9kYEqlDgxnWa9xpVgoBpO36HGVv5WH...         Cozy Shroud
# 2   _R4cErxtKyHB5fEb-7HKj0RgdF49C01NM8mKgPqaRMjUJy...              þowerD
# 3      __S_bzD-vAZ6Ku6tg3rm7VFXx0Bgt3JWtyOunOkmbIPoTA               5fire
# 4   2xSjkLDwRA-TK466OkvP99zWvJ22so6_aJPA1HC9Auzax4...    Serious Gameplay
# 5   iVJddGNhzsW5WPDpM4GSDBF6vu3TmzAdniicGHKgn2zZZW...    pspspspsmeowmeow
# 6   m2sKKYwWJaJ9dl3zHuCoY_mlp6_6i-FipyMH7kubEN65Uv...         Tempest ttv
# 7      AIQhIQFuZWX233O9nuKtI3LMxtEAfV2qm0MiUkyz0b4KjA             Dragoon
# 8   IDDxiWI94jjyAW_pcr1NfZzKEuMyCXlKcs1eG-6-Lb-g4T...      Pieck is Waifu
# 9      NMl4mIYIfnPAAH6pT2fyTmmNxutH5V3rJNKW1nCNMCVCRw        I like Booba
# 10  ZkKBXQuS10T_f11ig3eLkw53lDHAhfVB3kG58ud16XsFRQ...       LeenK Nirvana
# 11  6kCLRADAr-TCB1ME03ND1QUGhSQPJ6rPlegZBLJ6DJmclK...    unga bunga kindo
# 12     __S_bzD-vAZ6Ku6tg3rm7VFXx0Bgt3JWtyOunOkmbIPoTA               5fire
# 13     h0n6KNRFD6rwSz2MBLQt3gs9SXdOxZ2y3a6OI3wKO4H71g            Good Boi
# 14  IDDxiWI94jjyAW_pcr1NfZzKEuMyCXlKcs1eG-6-Lb-g4T...      Pieck is Waifu
# 15     bB8DIPu6VGXo1lTNV9RR0WGAwUogiRYm8xmr36RX2xjTEA    Alicopter T3 Sub
# 16     2dLxZoMRMrRzmgNiCSgA4lezuZmOMvLZJff0xQTMteKRRQ          WC Qwacker
# 17     ii2YY7ub39QQCOdaAMjv--q9Ql2IkzJ1K-rwcdPuZj9RBg          Doublelift
# 18  0zb2VIVo-FBqIk98mDAQxGS-P2HCr02zk71Gd0vVNxchEs...           depresion
# 19    SysnZS-sN9AeZMW4GHy098_jbQ_1SP4vW11He7IG_AD-mns        Draven696969
#
#                                     player.summonerId  participantId    win  \
# 0     iqHggxw_J_90RXfoSzAqi9ITv-LmDdIFSFS-4z_qinnQnOY              1  False
# 1    zWQ1A_8FaR9psysYLIyS7MaCkAsXULSh_ZzGKRpsdpOqz6kw              2  False
# 2    0Sr4OjKxiEe105n6xEPW-S1USPKmNZBia4_AEAZyZJKZXwil              3  False
# 3     BUcAS_iVJVxAmCVqg8eG3NDvbnTp8wsT0l-wNS4EqYX96gk              4  False
# 4   sEqx0bfTMJiY52ZU831U6oBCdfv1sNgqk68Vj9LC32zjX1...              5  False
# 5    YcwF5hr5accBvq5VVWUajUmBIvokhmHByuDvyfRbInzZesut              6   True
# 6   EGMOeHLfeFw6cBjepKxMrsmUJ5oWfSNykvvVGhYcL6CdwV...              7   True
# 7     fVsMYQwM9zSqU09guMSgT2goBDQ5g1zQILvMrPQQoYed9-k              8   True
# 8    ne0WA3Mou5W67K3tGO1iUc3vR93VeHQCbsY2N_H5ucKzcY1_              9   True
# 9     mwYYtJgmLE7hQpFW58joBVtXzLHJRISR5jHcwFKUy84CNxg             10   True
# 10  so1qNAuD0x-wZErhV8jy6Rt6dwIrgRcddX19lQxr7YfzIb...              1  False
# 11  6maffPrpsHpTUB0V76pVuA9jfx2Stl7FNBytsiwu5-1lE3...              2  False
# 12    BUcAS_iVJVxAmCVqg8eG3NDvbnTp8wsT0l-wNS4EqYX96gk              3  False
# 13    nkBcD59OcoUVL3lLWeusrgserBowbKA_uGojzZuqG4dggvM              4  False
# 14   ne0WA3Mou5W67K3tGO1iUc3vR93VeHQCbsY2N_H5ucKzcY1_              5  False
# 15    T6In7sIiiYxmE4Liqa6bPcHMKAZrSNVx6dvfx32aYd9xdkU              6   True
# 16    eJDIDpmUOZShw96ReM1NuDZA2AySCmFW5Tdvgp0UOiWHTQY              7   True
# 17    iqHggxw_J_90RXfoSzAqi9ITv-LmDdIFSFS-4z_qinnQnOY              8   True
# 18  Qp1UYzo-Mp3i9BmhoTj2wruTR5YdyzbUQF8ILh4v9jeP7L...              9   True
# 19    luFgRdKx312jCmdeLV-CLv2GY_50A-PnOcAF3aLHjO6iJkE             10   True
#
#     item0  item1  item2  item3  item4  ...  perk4Var3  perk5  perk5Var1  \
# 0    1055   6671   2055   3006      0  ...          0   8135        101
# 1    3044   6029      0   1054   1055  ...          0   8453        366
# 2    3067      0   3044   1001      0  ...          0   8105          1
# 3       0   3191   3802   1082   3158  ...          0   8347          0
# 4    2055   3117   3067   3105      0  ...          0   8321          1
# 5    3158   3068   1011   1057      0  ...          0   8429         25
# 6    6673   1054   1055   3006   3086  ...         12   8453        190
# 7    1028   6029   3076   3047   1036  ...          0   8473        484
# 8    6671   1055   3006   1037   3036  ...          0   8345          3
# 9    2065   3853      0   3158   3067  ...          0   8345          3
# 10   3179   3047   6692   3133   3035  ...          0   8135       1846
# 11   6673   3508   3006   1057   3051  ...          0   8345          3
# 12   4636   3020   1058   1056   1058  ...          0   8224        603
# 13   2031   2065   3853   3158   1004  ...          0   8453        230
# 14   6671   1055   3006   3036      0  ...          5   8345          3
# 15   6656   4629   3157      0   1082  ...          0   8347          0
# 16   3078   3047   3074   1055   3044  ...          0   8242         31
# 17   1055   6672   3085   3031   1053  ...          0   8135       2681
# 18      0   3190   3857   1006   3067  ...          0   8306         15
# 19   3041   3157   3916   2055   3020  ...          0   8232          3
#
#     perk5Var2  perk5Var3  perkPrimaryStyle  perkSubStyle  statPerk0  \
# 0           3          0              8000          8100       5005
# 1           0          0              8000          8400       5008
# 2           0          0              8000          8100       5008
# 3           0          0              8000          8300       5008
# 4           0          0              8400          8300       5007
# 5          15         16              8000          8400       5007
# 6         169          0              8000          8400       5005
# 7           0          0              8000          8400       5005
# 8           0          0              8000          8300       5005
# 9           0          0              8400          8300       5008
# 10          4          0              8000          8100       5008
# 11          0          0              8000          8300       5005
# 12          0          0              8100          8200       5008
# 13       1712          0              8200          8400       5008
# 14          0          0              8000          8300       5005
# 15          0          0              8000          8300       5008
# 16          0          0              8000          8400       5008
# 17          5          0              8000          8100       5005
# 18          0          0              8400          8300       5005
# 19         30          0              8100          8200       5005
#
#     statPerk1  statPerk2
# 0        5008       5002
# 1        5008       5002
# 2        5008       5002
# 3        5008       5002
# 4        5002       5003
# 5        5002       5001
# 6        5008       5003
# 7        5008       5002
# 8        5008       5002
# 9        5008       5002
# 10       5008       5002
# 11       5008       5002
# 12       5008       5003
# 13       5008       5002
# 14       5008       5002
# 15       5008       5002
# 16       5008       5002
# 17       5008       5002
# 18       5002       5003
# 19       5008       5002
#
# [20 rows x 105 columns]

# %%
pd.set_option('display.max_rows', 150)

# %%
df
# Out:
#                                      player.accountId player.summonerName  \
# 0      ii2YY7ub39QQCOdaAMjv--q9Ql2IkzJ1K-rwcdPuZj9RBg          Doublelift
# 1   Cl4YEkXtBJnME7eH9kYEqlDgxnWa9xpVgoBpO36HGVv5WH...         Cozy Shroud
# 2   _R4cErxtKyHB5fEb-7HKj0RgdF49C01NM8mKgPqaRMjUJy...              þowerD
# 3      __S_bzD-vAZ6Ku6tg3rm7VFXx0Bgt3JWtyOunOkmbIPoTA               5fire
# 4   2xSjkLDwRA-TK466OkvP99zWvJ22so6_aJPA1HC9Auzax4...    Serious Gameplay
# 5   iVJddGNhzsW5WPDpM4GSDBF6vu3TmzAdniicGHKgn2zZZW...    pspspspsmeowmeow
# 6   m2sKKYwWJaJ9dl3zHuCoY_mlp6_6i-FipyMH7kubEN65Uv...         Tempest ttv
# 7      AIQhIQFuZWX233O9nuKtI3LMxtEAfV2qm0MiUkyz0b4KjA             Dragoon
# 8   IDDxiWI94jjyAW_pcr1NfZzKEuMyCXlKcs1eG-6-Lb-g4T...      Pieck is Waifu
# 9      NMl4mIYIfnPAAH6pT2fyTmmNxutH5V3rJNKW1nCNMCVCRw        I like Booba
# 10  ZkKBXQuS10T_f11ig3eLkw53lDHAhfVB3kG58ud16XsFRQ...       LeenK Nirvana
# 11  6kCLRADAr-TCB1ME03ND1QUGhSQPJ6rPlegZBLJ6DJmclK...    unga bunga kindo
# 12     __S_bzD-vAZ6Ku6tg3rm7VFXx0Bgt3JWtyOunOkmbIPoTA               5fire
# 13     h0n6KNRFD6rwSz2MBLQt3gs9SXdOxZ2y3a6OI3wKO4H71g            Good Boi
# 14  IDDxiWI94jjyAW_pcr1NfZzKEuMyCXlKcs1eG-6-Lb-g4T...      Pieck is Waifu
# 15     bB8DIPu6VGXo1lTNV9RR0WGAwUogiRYm8xmr36RX2xjTEA    Alicopter T3 Sub
# 16     2dLxZoMRMrRzmgNiCSgA4lezuZmOMvLZJff0xQTMteKRRQ          WC Qwacker
# 17     ii2YY7ub39QQCOdaAMjv--q9Ql2IkzJ1K-rwcdPuZj9RBg          Doublelift
# 18  0zb2VIVo-FBqIk98mDAQxGS-P2HCr02zk71Gd0vVNxchEs...           depresion
# 19    SysnZS-sN9AeZMW4GHy098_jbQ_1SP4vW11He7IG_AD-mns        Draven696969
#
#                                     player.summonerId  participantId    win  \
# 0     iqHggxw_J_90RXfoSzAqi9ITv-LmDdIFSFS-4z_qinnQnOY              1  False
# 1    zWQ1A_8FaR9psysYLIyS7MaCkAsXULSh_ZzGKRpsdpOqz6kw              2  False
# 2    0Sr4OjKxiEe105n6xEPW-S1USPKmNZBia4_AEAZyZJKZXwil              3  False
# 3     BUcAS_iVJVxAmCVqg8eG3NDvbnTp8wsT0l-wNS4EqYX96gk              4  False
# 4   sEqx0bfTMJiY52ZU831U6oBCdfv1sNgqk68Vj9LC32zjX1...              5  False
# 5    YcwF5hr5accBvq5VVWUajUmBIvokhmHByuDvyfRbInzZesut              6   True
# 6   EGMOeHLfeFw6cBjepKxMrsmUJ5oWfSNykvvVGhYcL6CdwV...              7   True
# 7     fVsMYQwM9zSqU09guMSgT2goBDQ5g1zQILvMrPQQoYed9-k              8   True
# 8    ne0WA3Mou5W67K3tGO1iUc3vR93VeHQCbsY2N_H5ucKzcY1_              9   True
# 9     mwYYtJgmLE7hQpFW58joBVtXzLHJRISR5jHcwFKUy84CNxg             10   True
# 10  so1qNAuD0x-wZErhV8jy6Rt6dwIrgRcddX19lQxr7YfzIb...              1  False
# 11  6maffPrpsHpTUB0V76pVuA9jfx2Stl7FNBytsiwu5-1lE3...              2  False
# 12    BUcAS_iVJVxAmCVqg8eG3NDvbnTp8wsT0l-wNS4EqYX96gk              3  False
# 13    nkBcD59OcoUVL3lLWeusrgserBowbKA_uGojzZuqG4dggvM              4  False
# 14   ne0WA3Mou5W67K3tGO1iUc3vR93VeHQCbsY2N_H5ucKzcY1_              5  False
# 15    T6In7sIiiYxmE4Liqa6bPcHMKAZrSNVx6dvfx32aYd9xdkU              6   True
# 16    eJDIDpmUOZShw96ReM1NuDZA2AySCmFW5Tdvgp0UOiWHTQY              7   True
# 17    iqHggxw_J_90RXfoSzAqi9ITv-LmDdIFSFS-4z_qinnQnOY              8   True
# 18  Qp1UYzo-Mp3i9BmhoTj2wruTR5YdyzbUQF8ILh4v9jeP7L...              9   True
# 19    luFgRdKx312jCmdeLV-CLv2GY_50A-PnOcAF3aLHjO6iJkE             10   True
#
#     item0  item1  item2  item3  item4  ...  perk4Var3  perk5  perk5Var1  \
# 0    1055   6671   2055   3006      0  ...          0   8135        101
# 1    3044   6029      0   1054   1055  ...          0   8453        366
# 2    3067      0   3044   1001      0  ...          0   8105          1
# 3       0   3191   3802   1082   3158  ...          0   8347          0
# 4    2055   3117   3067   3105      0  ...          0   8321          1
# 5    3158   3068   1011   1057      0  ...          0   8429         25
# 6    6673   1054   1055   3006   3086  ...         12   8453        190
# 7    1028   6029   3076   3047   1036  ...          0   8473        484
# 8    6671   1055   3006   1037   3036  ...          0   8345          3
# 9    2065   3853      0   3158   3067  ...          0   8345          3
# 10   3179   3047   6692   3133   3035  ...          0   8135       1846
# 11   6673   3508   3006   1057   3051  ...          0   8345          3
# 12   4636   3020   1058   1056   1058  ...          0   8224        603
# 13   2031   2065   3853   3158   1004  ...          0   8453        230
# 14   6671   1055   3006   3036      0  ...          5   8345          3
# 15   6656   4629   3157      0   1082  ...          0   8347          0
# 16   3078   3047   3074   1055   3044  ...          0   8242         31
# 17   1055   6672   3085   3031   1053  ...          0   8135       2681
# 18      0   3190   3857   1006   3067  ...          0   8306         15
# 19   3041   3157   3916   2055   3020  ...          0   8232          3
#
#     perk5Var2  perk5Var3  perkPrimaryStyle  perkSubStyle  statPerk0  \
# 0           3          0              8000          8100       5005
# 1           0          0              8000          8400       5008
# 2           0          0              8000          8100       5008
# 3           0          0              8000          8300       5008
# 4           0          0              8400          8300       5007
# 5          15         16              8000          8400       5007
# 6         169          0              8000          8400       5005
# 7           0          0              8000          8400       5005
# 8           0          0              8000          8300       5005
# 9           0          0              8400          8300       5008
# 10          4          0              8000          8100       5008
# 11          0          0              8000          8300       5005
# 12          0          0              8100          8200       5008
# 13       1712          0              8200          8400       5008
# 14          0          0              8000          8300       5005
# 15          0          0              8000          8300       5008
# 16          0          0              8000          8400       5008
# 17          5          0              8000          8100       5005
# 18          0          0              8400          8300       5005
# 19         30          0              8100          8200       5005
#
#     statPerk1  statPerk2
# 0        5008       5002
# 1        5008       5002
# 2        5008       5002
# 3        5008       5002
# 4        5002       5003
# 5        5002       5001
# 6        5008       5003
# 7        5008       5002
# 8        5008       5002
# 9        5008       5002
# 10       5008       5002
# 11       5008       5002
# 12       5008       5003
# 13       5008       5002
# 14       5008       5002
# 15       5008       5002
# 16       5008       5002
# 17       5008       5002
# 18       5002       5003
# 19       5008       5002
#
# [20 rows x 105 columns]
